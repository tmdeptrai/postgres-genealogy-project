# %%
import pandas as pd #legal import btw
import matplotlib.pyplot as plt
import numpy as np

# %%
#ETL: E-Extract, T-Transform, L-Load

#Extract from .csv file first
df = pd.read_csv("./raw_data/mariages_L3_5k.csv",encoding='utf-8',header=None)
df.columns = [
    'act_id', 'act_type',
    'a_last_name', 'a_first_name', 'a_father_first_name',
    'a_mother_last_name', 'a_mother_first_name',
    'b_last_name', 'b_first_name', 'b_father_first_name', 
    'b_mother_last_name', 'b_mother_first_name',
    'commune_name', 'department_id', 'act_date', 'view_number'
]

df
# Out:
#       act_id act_type a_last_name          a_first_name a_father_first_name  \
# 0          1  Mariage      ABADIE     Ferdinand Isidore                 NaN
# 1          2  Mariage      ABADIE     Ferdinand Isidore                 NaN
# 2          3  Mariage      ABADIE  Henri Louis François                 NaN
# 3          4  Mariage      ABADIE          Jean Auguste       Jean François
# 4          5  Mariage      ABADIE         Jean Baptiste                 NaN
# ...      ...      ...         ...                   ...                 ...
# 4995    4996  Mariage    ANGIBAUD         Pierre Julien     Pierre Julien +
# 4996    4997  Mariage    ANGIBAUD   Pierre Louis Joseph               Louis
# 4997    4998  Mariage    ANGIBAUD   Pierre Louis Joseph                 NaN
# 4998    4999  Mariage    ANGIBAUD        Pierre Pasckal                 NaN
# 4999    5000  Mariage    ANGIBAUD         Pierre Victor              Pierre
#
# ...

# %%
# Summary
df.astype('object').describe()
# Out:
#         act_id act_type a_last_name a_first_name a_father_first_name  \
# count     5000     5000        5000         4987                2443
# unique    5000        7         394          798                 278
# top          1  Mariage      ALBERT       Pierre              Pierre
# freq         1     4638         843          738                 315
#
#        a_mother_last_name a_mother_first_name b_last_name b_first_name  \
# count                2384                2392        4991         4985
# unique               1157                 292        2340          961
# top              PIVETEAU               Marie      MOREAU        Marie
# freq                   20                 533          31          986
#
#        b_father_first_name b_mother_last_name b_mother_first_name  \
# count                 2533               2480                2477
# unique                 319               1356                 345
# ...

# %%
# Count number of null(NaN) values for each column
df.isna().sum()
# Out:
# act_id                    0
# act_type                  0
# a_last_name               0
# a_first_name             13
# a_father_first_name    2557
# a_mother_last_name     2616
# a_mother_first_name    2608
# b_last_name               9
# b_first_name             15
# b_father_first_name    2467
# b_mother_last_name     2520
# b_mother_first_name    2523
# commune_name              0
# department_id             0
# act_date                328
# view_number             877
# dtype: int64

# %%
print(np.unique(df['act_type']))
# Out:
# ['Certificat de mariage' 'Contrat de mariage' 'Divorce' 'Mariage'
#  'Promesse de mariage - fiançailles' 'Publication de mariage'
#  'Rectification de mariage']

# %%
#Transform:
#idk what do we do?
