# %%
import pandas as pd #legal import btw
import matplotlib.pyplot as plt
import numpy as np

# %%
#ETL: E-Extract, T-Transform, L-Load

#Extract from .csv file first
df = pd.read_csv("./mariages_L3_5k.csv",encoding='utf-8',header=None)
df.columns = [
    'act_id', 'act_type',
    'person_a_last_name', 'person_a_first_name', 'person_a_father_first_name',
    'person_a_mother_last_name', 'person_a_mother_first_name',
    'person_b_last_name', 'person_b_first_name', 'person_b_father_first_name', 
    'person_b_mother_last_name', 'person_b_mother_first_name',
    'commune_name', 'department_id', 'act_date', 'view_number'
]

df
# Out:
#       act_id act_type person_a_last_name   person_a_first_name  \
# 0          1  Mariage             ABADIE     Ferdinand Isidore
# 1          2  Mariage             ABADIE     Ferdinand Isidore
# 2          3  Mariage             ABADIE  Henri Louis François
# 3          4  Mariage             ABADIE          Jean Auguste
# 4          5  Mariage             ABADIE         Jean Baptiste
# ...      ...      ...                ...                   ...
# 4995    4996  Mariage           ANGIBAUD         Pierre Julien
# 4996    4997  Mariage           ANGIBAUD   Pierre Louis Joseph
# 4997    4998  Mariage           ANGIBAUD   Pierre Louis Joseph
# 4998    4999  Mariage           ANGIBAUD        Pierre Pasckal
# 4999    5000  Mariage           ANGIBAUD         Pierre Victor
#
#      person_a_father_first_name person_a_mother_last_name  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# ...

# %%
# Summary
df.astype('object').describe()
# Out:
#         act_id act_type person_a_last_name person_a_first_name  \
# count     5000     5000               5000                4987
# unique    5000        7                394                 798
# top          1  Mariage             ALBERT              Pierre
# freq         1     4638                843                 738
#
#        person_a_father_first_name person_a_mother_last_name  \
# count                        2443                      2384
# unique                        278                      1157
# top                        Pierre                  PIVETEAU
# freq                          315                        20
#
#        person_a_mother_first_name person_b_last_name person_b_first_name  \
# count                        2392               4991                4985
# unique                        292               2340                 961
# top                         Marie             MOREAU               Marie
# ...

# %%
# Count number of null(NaN) values for each column
df.isna().sum()
# Out:
# act_id                           0
# act_type                         0
# person_a_last_name               0
# person_a_first_name             13
# person_a_father_first_name    2557
# person_a_mother_last_name     2616
# person_a_mother_first_name    2608
# person_b_last_name               9
# person_b_first_name             15
# person_b_father_first_name    2467
# person_b_mother_last_name     2520
# person_b_mother_first_name    2523
# commune_name                     0
# department_id                    0
# act_date                       328
# view_number                    877
# dtype: int64

# %%
#Transform:
#idk what do we do?
